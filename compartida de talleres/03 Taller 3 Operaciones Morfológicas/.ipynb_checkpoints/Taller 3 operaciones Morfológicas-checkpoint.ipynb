# %% [markdown]
# # Taller #3 Operaciones Morfológicas.
# Integrantes:
#     - Alejandra Arias Torres
#     - Leonardo Fabio Mercado Benítez

# %%
import numpy as np
import cv2 
from matplotlib import pyplot as plt
print('Librerias importadas correctamente')
# Out:
# Librerias importadas correctamente

# %%
img_p = cv2.imread('Fig/manoP.png',0)
img_g = cv2.imread('Fig/manoG.jpg',0)
ret,img_p_bin = cv2.threshold(img_p,127,255,cv2.THRESH_BINARY)
ret,img_g_bin = cv2.threshold(img_g,175,255,cv2.THRESH_BINARY)
print('Las imagenes a trabajar son:')

plt.figure(1)
plt.subplot(2,2,1), plt.imshow(img_p,cmap='gray'),plt.title('Mano P')
plt.subplot(2,2,2), plt.imshow(img_g,cmap='gray'),plt.title('Mano G')
plt.subplot(2,2,3), plt.imshow(img_p_bin,cmap='gray'),plt.title('Mano P Binaria')
plt.subplot(2,2,4), plt.imshow(img_g_bin,cmap='gray'),plt.title('Mano G Binaria')
plt.subplots_adjust(left = 0.125, right = 3 ,  bottom = 0.1, top = 1.8, wspace = 0.04, hspace = 0.2 )
plt.show()
# Out:
# Las imagenes a trabajar son:

# %% [markdown]
# ### Operaciones Básicas

# %% [markdown]
# ###### 1. Dilatación

# %%
kernel1 = np.ones((3,3))
dilatation = cv2.dilate(img_p_bin,kernel1,iterations=1)

# %% [markdown]
# ###### 2. Erosión

# %% [markdown]
# ###### 3. Apertura

# %% [markdown]
# ###### 4. Cierre

# %% [markdown]
# ### Transformaciones

# %% [markdown]
# ###### 1. Transformada de Hit or Miss

# %% [markdown]
# ### Algoritmos Morfológicos

# %% [markdown]
# ###### 1. Extracción de Fronteras

# %% [markdown]
# ###### 2. Llenado de Regiones

# %% [markdown]
# ###### 3. Extracción de componentes conectados

# %% [markdown]
# ###### 4. Adelgazamiento

# %% [markdown]
# ###### 5. Engrosamiento

# %% [markdown]
# ###### 6. Esqueleto
