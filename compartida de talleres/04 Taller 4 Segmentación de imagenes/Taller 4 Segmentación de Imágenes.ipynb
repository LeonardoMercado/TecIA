# %% [markdown]
# # Taller #4 Segmentación de Imágenes:
# Integrantes:
# - Maria Alejanda Arias Torres.
# - Leonardo Fabio Mercado Benítez.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
print('Librerias importadas exitosamente')
# Out:
# Librerias importadas exitosamente

# %%
img_1 = cv2.imread('Fig/manoG.jpg',0)
img_2 = cv2.imread('Fig/manoP.png',0)

plt.figure(1)
plt.subplot(1,2,1), plt.imshow(img_1,cmap='gray'), plt.title('Mano 1')
plt.subplot(1,2,2), plt.imshow(img_2,cmap='gray'), plt.title('Mano 2')
plt.subplots_adjust(right=1.5)
plt.show()

# %% [markdown]
# ---
# ## Contornos:

# %% [markdown]
# #### Encuentra Contornos:
#
# Hablar además de:
#     - Mode.
#     - Method.
#     - Dibujo del contorno.

# %% [markdown]
# #### Transformada de Hough

# %% [markdown]
# ##### Método Estándar
# cv2.HoughLines

# %% [markdown]
# ##### Método probabilístico
# cv2.HoughLinesP

# %% [markdown]
# ##### Encuentra círculos
# cv2.HoghCircles

# %% [markdown]
# ---
# ## Similitud:

# %% [markdown]
# #### Crecimiento de Regiones:
# cv2.floodFill

# %% [markdown]
# #### Algoritmo de Watershed:
# cv2.watershed
