# %% [markdown]
# # Taller #5 Extracción de Características
#
# Integrantes:
#
# - Alejandra Arias.
# - Leonardo Fabio Mercado Benítez.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
print('Librerias importadas correctamente')
# Out:
# Librerias importadas correctamente

# %% [markdown]
# #### Perímetro

# %%
img1 = cv2.imread('Fig/1.jpg',0)
gray_image = cv2.convertScaleAbs(img1)
#_,img1 = cv2.threshold(img1,140,255,cv2.THRESH_BINARY)
plt.imshow(gray_image)
plt.show()

# %%
coefficient = .05
perimetro = coefficient * cv2.arcLength(img1,True)
perimetro
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-7ff42ed54a59> in <module>
#       1 coefficient = .05
# ----> 2 perimetro = coefficient * cv2.arcLength(img1,True)
#       3 perimetro
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\shapedescr.cpp:280: error: (-215:Assertion failed) count >= 0 && (depth == CV_32F || depth == CV_32S) in function 'cv::arcLength'

# %% [markdown]
# #### Área

# %% [markdown]
# #### Delimitar Contorno

# %% [markdown]
# ##### Delimitar Contorno Cuadrados:

# %% [markdown]
# ##### Delimitar Contorno Rectangulos:

# %% [markdown]
# ##### Delimitar Contorno Círculos:

# %% [markdown]
# ##### Delimitar Contorno Elípses:

# %% [markdown]
# #### Momentos:

# %% [markdown]
# #### Momentos de Hu:
